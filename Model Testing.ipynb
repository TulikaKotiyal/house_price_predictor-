# %% [markdown]
# ## Using the Model

# %%
from joblib import dump, load
import numpy as np
model = load('Dragon.joblib')

# %%
features = np.array([[-0.40172693,  2.95931752, -1.06665188, -0.27808871, -1.39916607,
       -0.29339396, -1.30744293,  2.54258088, -0.97404758, -0.53644549,
       -0.86180042,  0.40033245, -0.82902046]])
model.predict(features)
# Out:
# array([23.13702915])
